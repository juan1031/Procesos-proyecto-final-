# %%
import random as r
def dado():
    a = r.randrange(1,7)
    return a
def juego(): 
    
    cant_j = int(input('Ingrese el numero de jugadores:\n '))
    apuesta = int(input('Ingrese el valor inicial de la apuesta:\n '))
    if apuesta < 100:
        apuesta = int(input('Error, no es válido. Ingrese un nuevo valor:\n'))
    m = list(range(1,cant_j+1))
    l = {}
    for i in m:
        n= 1000-apuesta
        l.append([n])   
    if apuesta >= 100:
        cuenta1 = cant_j * apuesta
    
    pozo = int(cuenta1)
    turno = 0
    
    while pozo>0:
        x = dado()
        y = dado()
        turno+=1
        print('jugador',turno)
        print('Primer lanzamiento: ',x)
        comisión = 0.05
        casino = 0
        
        if x == 1:
            pozo += apuesta
            print ('Pozo:',pozo)
            l[turno-1][]
        if x == 6:
            casino = pozo*comisión
            pozo = (pozo-casino)-apuesta
            print ('Pozo:',pozo)
        if 1<x<6:
            casino_alerta = pozo*comisión
            pozo_alerta = (pozo-casino_alerta)
            apuestaa = int(input(f'Ingrese el valor a apostar que no sea mayor a {int(pozo_alerta)}: '))
            print ('Segundo lanzamiento: ',y)
            if x<y:
                casino = pozo*comisión
                pozo = (pozo-casino)-apuestaa
            elif pozo<apuesta:
                print('Error, la apuesta es mayor que pozo')
                print('Pozo:',pozo)
            if x>=y:
                pozo = pozo+apuestaa
                print('Pozo:',pozo)
            
        if turno>=cant_j:
            turno = 0
            print(' ')
        if pozo == 0:
            print('Pozo:', int(pozo))
            print('Fin del juego')

juego()
# Out:
# Ingrese el numero de jugadores:
#  3
# Ingrese el valor inicial de la apuesta:
#  100
# jugador 1
# Primer lanzamiento:  1
# Pozo: 400
# jugador 2
# Primer lanzamiento:  6
# Pozo: 280.0
# jugador 3
# Primer lanzamiento:  5
# Ingrese el valor a apostar que no sea mayor a 266: 200
# Segundo lanzamiento:  6
#
# jugador 1
# Primer lanzamiento:  1
# Pozo: 166.0
# jugador 2
# Primer lanzamiento:  1
# Pozo: 266.0
# jugador 3
# Primer lanzamiento:  1
# Pozo: 366.0
#
# jugador 1
# Primer lanzamiento:  5
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_14200/1460036400.py in <module>
#      55             print('Fin del juego')
#      56
# ---> 57 juego()
#
# ~\AppData\Local\Temp/ipykernel_14200/1460036400.py in juego()
#      36             casino_alerta = pozo*comisión
#      37             pozo_alerta = (pozo-casino_alerta)
# ---> 38             apuestaa = int(input(f'Ingrese el valor a apostar que no sea mayor a {int(pozo_alerta)}: '))
#      39             print ('Segundo lanzamiento: ',y)
#      40             if x<y:
#
# ~\anaconda3\lib\site-packages\ipykernel\kernelbase.py in raw_input(self, prompt)
#    1004                 "raw_input was called, but this frontend does not support input requests."
#    1005             )
# -> 1006         return self._input_request(
#    1007             str(prompt),
#    1008             self._parent_ident["shell"],
#
# ~\anaconda3\lib\site-packages\ipykernel\kernelbase.py in _input_request(self, prompt, ident, parent, password)
#    1049             except KeyboardInterrupt:
#    1050                 # re-raise KeyboardInterrupt, to truncate traceback
# -> 1051                 raise KeyboardInterrupt("Interrupted by user") from None
#    1052             except Exception:
#    1053                 self.log.warning("Invalid Message:", exc_info=True)
#
# KeyboardInterrupt: Interrupted by user

# %%
import random as r
def dado():
    a = r.randrange(1,7)
    return a
def juego(): 
    
    cant_j = 3
    apuesta = 200
    jugadores = list(range(1,cant_j+1))
    l = {}
    for jugador in jugadores:
        n= 1000-apuesta
        l[jugador] = n 
    pozo= cant_j * apuesta    
    turno = 1
    
    while pozo>0:
        x = dado()
        print('jugador',turno)
        print('Primer lanzamiento: ',x)
        comision = 0.05
        casino = 0
        
        if x == 1:
            pozo += apuesta
            print ('Pozo:',pozo)
        if x == 6:
            pozo = pozo-apuesta
            print ('Pozo:',pozo)
            l[turno]+=apuesta 
        else:
            if x<=3:
                print("Apuesto al mayor")
                if dado()>x:
                    print("Ganaste")
                    casino_alerta = pozo*comision
                    pozo_alerta = (pozo-casino_alerta)
                    break
                else:
                    print("Perdiste, ahora es el turno del siguiente jugador")
            if x>3:
                print("Apuesto al menor")
                if dado()<x:
                    print("Ganaste")
                    casino_alerta = pozo*comision
                    pozo_alerta = (pozo-casino_alerta)
                    break
                else:
                    print("Perdiste, ahora es el turno del siguiente jugador")
            
        if turno>=cant_j:
            turno = 0
            print(' ')
        if pozo == 0:
            print('Pozo:', int(pozo))
            print('Fin del juego')
        turno+=1 

juego()
# Out:
# jugador 1
# Primer lanzamiento:  2
# Apuesto al mayor
# Perdiste, ahora es el turno del siguiente jugador
# jugador 2
# Primer lanzamiento:  5
# Apuesto al menor
# Ganaste

# %% [markdown]
# ***
