# %%
import random as r
def dado():
    a = r.randrange(1,7)
    return a

def inicio():
    cant_j = int(input('Ingrese el numero de jugadores:\n '))
    apuesta = int(input('Ingrese el valor inicial de la apuesta:\n '))
    if apuesta < 100:
        apuesta = int(input('Error, no es válido. Ingrese un nuevo valor:\n'))
    m = list(range(1,cant_j+1))
    l = []
    for i in m:
        l = l.append([1000-apuesta])   
    if apuesta >= 100:
        cuenta1 = cant_j * apuesta
        
    return cant_j, apuesta, l, cuenta1 
    
inicio()

# %%
def juego(): 
    
    pozo = int(pozo_inicial())
    turno = 0
    
    while pozo>0:
        x = dado()
        y = dado()
        turno+=1
        print('jugador',turno)
        print('Primer lanzamiento: ',x)
        comisión = 0.05
        casino = 0
        
        jugador1 = (turno==1)
        
        if x == 1:
            pozo += apuesta
            print ('Pozo:',pozo)
        if x == 6:
            casino = pozo*comisión
            pozo = (pozo-casino)-apuesta
            print ('Pozo:',pozo)
        if 1<x<6:
            casino_alerta = pozo*comisión
            pozo_alerta = (pozo-casino_alerta)
            apuestaa = int(input(f'Ingrese el valor a apostar que no sea mayor a {int(pozo_alerta)} : '))
            print ('Segundo lanzamiento: ',y)
            if x<y:
                casino = pozo*comisión
                pozo = (pozo-casino)-apuestaa
            elif pozo<apuesta:
                print('Error, la apuesta es mayor que pozo')
                print('Pozo:',pozo)
            if x>=y:
                pozo = pozo+apuestaa
                print('Pozo:',pozo)
            
        if turno>=cant_j:
            turno = 0
            print(' ')
        if pozo == 0:
            print('Pozo:', int(pozo))
            print('Fin del juego')

juego()
# Out:
# jugador 1
# Primer lanzamiento:  3
# Ingrese el valor a apostar que no sea mayor a 380 : 100
# Segundo lanzamiento:  3
# Pozo: 500
# jugador 2
# Primer lanzamiento:  2
# Ingrese el valor a apostar que no sea mayor a 475 : 100
# Segundo lanzamiento:  1
# Pozo: 600
# jugador 3
# Primer lanzamiento:  5
# Ingrese el valor a apostar que no sea mayor a 570 : 100
# Segundo lanzamiento:  1
# Pozo: 700
# jugador 4
# Primer lanzamiento:  4
# Ingrese el valor a apostar que no sea mayor a 665 : 100
# Segundo lanzamiento:  4
# Pozo: 800
#
# jugador 1
# Primer lanzamiento:  2
# Ingrese el valor a apostar que no sea mayor a 760 : 100
# Segundo lanzamiento:  5
# jugador 2
# Primer lanzamiento:  5
# Ingrese el valor a apostar que no sea mayor a 627 : 100
# Segundo lanzamiento:  5
# Pozo: 760.0
# jugador 3
# Primer lanzamiento:  6
# Pozo: 622.0
# jugador 4
# Primer lanzamiento:  5
# Ingrese el valor a apostar que no sea mayor a 590 : 100
# Segundo lanzamiento:  4
# Pozo: 722.0
#
# jugador 1
# Primer lanzamiento:  3
# Ingrese el valor a apostar que no sea mayor a 685 : 200
# Segundo lanzamiento:  1
# Pozo: 922.0
# jugador 2
# Primer lanzamiento:  5
# Ingrese el valor a apostar que no sea mayor a 875 : 100
# Segundo lanzamiento:  5
# Pozo: 1022.0
# jugador 3
# Primer lanzamiento:  5
# Ingrese el valor a apostar que no sea mayor a 970 : 100
# Segundo lanzamiento:  2
# Pozo: 1122.0
# jugador 4
# Primer lanzamiento:  2
# Ingrese el valor a apostar que no sea mayor a 1065 : 100
# Segundo lanzamiento:  5
#
# jugador 1
# Primer lanzamiento:  5
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_3540/2128755683.py in <module>
#      41             print('Fin del juego')
#      42
# ---> 43 juego()
#
# ~\AppData\Local\Temp/ipykernel_3540/2128755683.py in juego()
#      22             casino_alerta = pozo*comisión
#      23             pozo_alerta = (pozo-casino_alerta)
# ---> 24             apuestaa = int(input(f'Ingrese el valor a apostar que no sea mayor a {int(pozo_alerta)} : '))
#      25             print ('Segundo lanzamiento: ',y)
#      26             if x<y:
#
# ~\anaconda3\lib\site-packages\ipykernel\kernelbase.py in raw_input(self, prompt)
#    1004                 "raw_input was called, but this frontend does not support input requests."
#    1005             )
# -> 1006         return self._input_request(
#    1007             str(prompt),
#    1008             self._parent_ident["shell"],
#
# ~\anaconda3\lib\site-packages\ipykernel\kernelbase.py in _input_request(self, prompt, ident, parent, password)
#    1049             except KeyboardInterrupt:
#    1050                 # re-raise KeyboardInterrupt, to truncate traceback
# -> 1051                 raise KeyboardInterrupt("Interrupted by user") from None
#    1052             except Exception:
#    1053                 self.log.warning("Invalid Message:", exc_info=True)
#
# KeyboardInterrupt: Interrupted by user

# %% [markdown]
# ***
